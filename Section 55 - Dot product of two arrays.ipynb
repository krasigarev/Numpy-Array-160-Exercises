# %%
import numpy as np

# %%
a = np.array([[1,2,3], [4,8,16]])
a
# Out:
# array([[ 1,  2,  3],
#        [ 4,  8, 16]])

# %%
b = np.array([5,6,11]).reshape(-1,1)
b
# Out:
# array([[ 5],
#        [ 6],
#        [11]])

# %%
np.dot(a,b)
# Out:
# array([[ 50],
#        [244]])
