# %%
import numpy as np

# %%
gfg = np.array([1,2,3,4,5,6])
print(gfg.__lt__(4))
# Out:
# [ True  True  True False False False]

# %%
gfg = np.array([[1,2,3,4,5,6],
                [6,5,4,3,2,1]])

print(gfg.__lt__(4))
# Out:
# [[ True  True  True False False False]
#  [False False False  True  True  True]]
