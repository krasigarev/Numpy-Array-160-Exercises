# %%
M1 = [
    [8,14,-6],
    [12,7,4],
    [-11,3,21]
]

print(M1)
# Out:
# [[8, 14, -6], [12, 7, 4], [-11, 3, 21]]

# %%
matrix_length = len(M1)
matrix_length
# Out:
# 3

# %%
for i in range(3):
    print(M1[i][-1])
# Out:
# -6
# 4
# 21
