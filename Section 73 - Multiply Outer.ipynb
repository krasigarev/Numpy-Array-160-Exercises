# %%
import numpy as np

# %%
a = np.array([1,2,3])
b = np.array([4,4,3])

c = np.multiply.outer(a, b)

print(c)
# Out:
# [[ 4  4  3]
#  [ 8  8  6]
#  [12 12  9]]

# %%
d = c.ravel()
print(d)
# Out:
# [ 4  4  3  8  8  6 12 12  9]
