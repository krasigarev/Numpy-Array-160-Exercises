# %%
import numpy as np

# %%
a = np.array([1,2])
b = np.array([3,4])

print(a)
print(b)
# Out:
# [1 2]
# [3 4]

# %%
c = np.append([a], [b], axis=0)
print(c)
# Out:
# [[1 2]
#  [3 4]]

# %%
c = np.append([a], [b], axis=1)
print(c)
# Out:
# [[1 2 3 4]]
