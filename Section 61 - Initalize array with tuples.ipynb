# %%
import numpy as np

# %%
a = np.full((3,2), np.nan, dtype='f,f')
print(a)
# Out:
# [[(nan, nan) (nan, nan)]
#  [(nan, nan) (nan, nan)]
#  [(nan, nan) (nan, nan)]]

# %%
a[0] = (12, 2)

print(a)
# Out:
# [[(12.,  2.) (12.,  2.)]
#  [(nan, nan) (nan, nan)]
#  [(nan, nan) (nan, nan)]]

# %%
a[1,1] = 13

# %%
print(a)
# Out:
# [[(12.,  2.) (12.,  2.)]
#  [(nan, nan) (13., 13.)]
#  [(nan, nan) (nan, nan)]]
