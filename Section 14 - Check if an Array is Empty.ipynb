# %%
import numpy as np

# %%
a = np.array([])
b = np.array([1,2])

# %%
def check_empty(x):
    if x.size == 0:
        print('Empty')
    else:
        print('Not Empty Array')

# %%
check_empty(a)
check_empty(b)
# Out:
# Empty
# Not Empty Array
