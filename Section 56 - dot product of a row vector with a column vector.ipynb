# %%
import numpy as np

# %%
a = np.array([1,2,3,4])
a
# Out:
# array([1, 2, 3, 4])

# %%
b = np.array([
    [4],
    [5],
    [6],
    [7]
])

b
# Out:
# array([[4],
#        [5],
#        [6],
#        [7]])

# %%
np.dot(a,b)
# Out:
# array([60])

# %%
a.dot(b)
# Out:
# array([60])
