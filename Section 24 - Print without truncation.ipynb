# %%
import numpy as np

# %%
x = np.arange(10000)
print('Before setting print option: ')
print(x)

import sys
np.set_printoptions(precision=4)

print('\n Print After setting option: ')
print(x)
# Out:
# Before setting print option:
# [   0    1    2 ... 9997 9998 9999]
#
#  Print After setting option:
# [   0    1    2 ... 9997 9998 9999]
