# %%
import numpy as np

# %%
a = np.arange(15, 33, 3)
b = a.reshape(2, 3)

print('a= ', a.shape)
print('\n After reshaping')
print('b= ', b.shape)
# Out:
# a=  (6,)
#
#  After reshaping
# b=  (2, 3)
