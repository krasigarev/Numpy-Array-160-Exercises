# %%
import numpy as np

# %%
a = np.array([[10,20], [30,40]])
b = a.flatten()
print('After Flatten: ', b)
# Out:
# After Flatten:  [10 20 30 40]

# %%
c = a.flatten('K')
print(c)
# Out:
# [10 20 30 40]
