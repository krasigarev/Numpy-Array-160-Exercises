# %%
import numpy as np

# %%
a = np.eye(2)
a
# Out:
# array([[1., 0.],
#        [0., 1.]])

# %%
b = np.array([[1,2], [3,4]])
print(b)
# Out:
# [[1 2]
#  [3 4]]

# %%
np.matmul(a,b)
# Out:
# array([[1., 2.],
#        [3., 4.]])

# %%
np.multiply(a,b)
# Out:
# array([[1., 0.],
#        [0., 4.]])
