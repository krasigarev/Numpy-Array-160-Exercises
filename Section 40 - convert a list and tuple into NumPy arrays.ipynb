# %%
import numpy as np

# %%
list_1 = [3,4,5,6]
print(type(list_1))
# Out:
# <class 'list'>

# %%
array1 = np.array(list_1)
print(type(array1))
# Out:
# <class 'numpy.ndarray'>

# %%
tuple1 = ([8,4,6], [1,2,3])
print(type(tuple1))
print(tuple1)
# Out:
# <class 'tuple'>
# ([8, 4, 6], [1, 2, 3])
