# %%
import numpy as np

# %%
x = np.array([1.1-2.2j])
print(x)
# Out:
# [1.1-2.2j]

# %%
print(x.dtype)
# Out:
# complex128

# %%
y = np.abs(x)
print(y)
# Out:
# [2.45967478]

# %%
t = np.imag(x)
print(t)
# Out:
# [-2.2]
