# %%
import numpy as np

# %%
empty = np.empty([2,2], dtype='i8')
print(empty)
# Out:
# [[       4294967296 23925768157396992]
#  [              960               768]]

# %%
print(empty.shape)
# Out:
# (2, 2)

# %%
print(empty.size)
# Out:
# 4
