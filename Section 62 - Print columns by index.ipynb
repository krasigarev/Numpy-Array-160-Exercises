# %%
import numpy as np

# %%
x = np.array([
    [1,10,18],
    [11,2,3]
])

print(x)
# Out:
# [[ 1 10 18]
#  [11  2  3]]

# %%
for i in range(3):
    print(i, x[:,i])
# Out:
# 0 [ 1 11]
# 1 [10  2]
# 2 [18  3]
