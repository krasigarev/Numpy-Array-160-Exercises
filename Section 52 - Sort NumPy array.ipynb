# %%
import numpy as np

# %%
x = np.array([[4,3],[2,1]])
x
# Out:
# array([[4, 3],
#        [2, 1]])

# %%
x.sort(axis=1)
x
# Out:
# array([[3, 4],
#        [1, 2]])

# %%
x.sort(axis=0)
x
# Out:
# array([[1, 2],
#        [3, 4]])
