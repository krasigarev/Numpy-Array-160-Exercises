# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
a = np.array([1,1,2])
b = np.array([5,6,5])
a + b
# Out:
# array([6, 7, 7])

# %%
a + 5
# Out:
# array([6, 6, 7])

# %%
M = np.ones((3,3))
M
# Out:
# array([[1., 1., 1.],
#        [1., 1., 1.],
#        [1., 1., 1.]])

# %%
M + a
# Out:
# array([[2., 2., 3.],
#        [2., 2., 3.],
#        [2., 2., 3.]])

# %%
a = np.arange(3)
b = np.arange(3)[:, np.newaxis]
print(a)
print(b)
print(a+b)
# Out:
# [0 1 2]
# [[0]
#  [1]
#  [2]]
# [[0 1 2]
#  [1 2 3]
#  [2 3 4]]

# %%
M = np.ones((3,3))
a = np.arange((3))
print(M.shape)
print(a.shape)
# Out:
# (3, 3)
# (3,)

# %%
M + a
# Out:
# array([[1., 2., 3.],
#        [1., 2., 3.],
#        [1., 2., 3.]])

# %%
M = np.ones((3,2))
a = np.arange((3))
print(M.shape)
print(a.shape)
# Out:
# (3, 2)
# (3,)

# %%
a[::,np.newaxis].shape
# Out:
# (3, 1)

# %%
M + a[:,np.newaxis]
# Out:
# array([[1., 1.],
#        [2., 2.],
#        [3., 3.]])

# %%
np.logaddexp(M, a[:, np.newaxis])
# Out:
# array([[1.31326169, 1.31326169],
#        [1.69314718, 1.69314718],
#        [2.31326169, 2.31326169]])

# %%
X = np.random.random((10,3))
X_mean = X.mean(0)
print(X_mean)
# Out:
# [0.55726784 0.4918377  0.39865901]

# %%
X_centered = X - X_mean
X_centered.mean(0)
# Out:
# array([ 7.77156117e-17, -1.11022302e-17,  1.11022302e-17])

# %%
x = np.linspace(0, 5, 50)
y = np.linspace(0, 5, 50)[:, np.newaxis]
z = np.sin(x) ** 10 + np.cos(10 + y + x) * np.cos(x)

plt.imshow(z, origin='lower', extent=[0,5,0,5], cmap='summer')
plt.colorbar()
