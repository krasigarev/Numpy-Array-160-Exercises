# %%
import numpy as np

# %%
p = np.array([])
q = np.array([3,2])
t = np.array([[1,2], [3,4]])

# %%
def get_elelments(x):
    return x.ndim and x.size

# %%
print(get_elelments(p))
print(get_elelments(q))
print(get_elelments(t))
# Out:
# 0
# 2
# 4
