# %%
from numpy.random import default_rng
import numpy as np

# %%
a = np.array([1,2,3])
b = np.array([7,8,9])

rng = default_rng()
rng.beta(a + 10, b + 10)
# Out:
# array([0.31784641, 0.54754612, 0.36604552])
