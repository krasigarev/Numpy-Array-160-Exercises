# %%
import numpy as np

# %%
a = np.array([[10,20,30], [100,200,300]])
print(a)
# Out:
# [[ 10  20  30]
#  [100 200 300]]

# %%
permutation = [1,0]
b = a[permutation]
print(b)
# Out:
# [[100 200 300]
#  [ 10  20  30]]
