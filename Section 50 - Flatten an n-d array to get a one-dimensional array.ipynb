# %%
import numpy as np

# %%
a = np.array([[1,2], [3,4]])
a
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
a.reshape(-1)
# Out:
# array([1, 2, 3, 4])

# %%
b = np.array([[1,2], [3,4]])
b
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
b.ravel()
# Out:
# array([1, 2, 3, 4])
