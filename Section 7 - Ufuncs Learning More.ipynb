# %%
import numpy as np

# %%
L = np.random.random(110)
sum(L)
# Out:
# np.float64(55.955149666743715)

# %%
np.sum(L)
# Out:
# np.float64(55.95514966674374)

# %%
big_array = np.random.rand(1000000)
# %timeit sum(big_array)
# %timeit np.sum(big_array)
# Out:
# 106 ms ± 1.4 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 968 μs ± 72.3 μs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %%
min(big_array)
# Out:
# np.float64(7.071203171893359e-07)

# %%
max(big_array)
# Out:
# np.float64(0.9999997207656334)

# %%
M =np.random.random((3,4))
print(M)
# Out:
# [[0.37497044 0.22944653 0.07452786 0.41843762]
#  [0.99939192 0.66974416 0.54717434 0.82711104]
#  [0.23097044 0.16283152 0.27950484 0.58540569]]

# %%
M.sum()
# Out:
# np.float64(5.399516404204364)

# %%
M.min(axis=0)
# Out:
# array([0.23097044, 0.16283152, 0.07452786, 0.41843762])

# %%
M.max(axis=0)
# Out:
# array([0.99939192, 0.66974416, 0.54717434, 0.82711104])

# %%
M.min(axis=1)
# Out:
# array([0.07452786, 0.54717434, 0.16283152])

# %%
M.max(axis=1)
# Out:
# array([0.41843762, 0.99939192, 0.58540569])
