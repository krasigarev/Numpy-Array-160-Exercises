# %%
import numpy as np

# %%
a  = np.array([2,3,4,5,6,7,8,10,33,23,67])
print(a)
# Out:
# [ 2  3  4  5  6  7  8 10 33 23 67]

# %%
b = np.partition(a, 5)
print(b)
# Out:
# [ 3  2  4  5  6  7  8 10 33 23 67]
