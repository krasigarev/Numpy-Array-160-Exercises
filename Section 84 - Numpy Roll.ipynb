# %%
import numpy as np

# %%
x = np.arange(1,7).reshape(2,3)
print(x)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %%
y = np.roll(x, 1, axis=1)
print(y)
# Out:
# [[3 1 2]
#  [6 4 5]]

# %%
y = np.roll(x, 1, axis=0)
print(y)
# Out:
# [[4 5 6]
#  [1 2 3]]
