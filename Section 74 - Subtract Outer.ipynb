# %%
import numpy as np

# %%
a, b = [2,7,8], [1,9]

c = np.abs(np.subtract.outer(a,b))
print('Original:\n', c)
# Out:
# Original:
#  [[1 7]
#  [6 2]
#  [7 1]]

# %%
d = c.ravel()
print(d)
# Out:
# [1 7 6 2 7 1]
