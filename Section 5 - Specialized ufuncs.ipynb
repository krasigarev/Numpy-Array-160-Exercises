# %%
import numpy as np
from scipy import special

# %%
x = [1,5,10]

print("gamma(x) = ", special.gamma(x))
print("In|gamma(x)| =", special.gammaln(x))
print("beta (x,2) =", special.beta(x, 2))
# Out:
# gamma(x) =  [1.0000e+00 2.4000e+01 3.6288e+05]
# In|gamma(x)| = [ 0.          3.17805383 12.80182748]
# beta (x,2) = [0.5        0.03333333 0.00909091]

# %%
x = np.array([0.3,0.7,0.8,1])
print("erf (x) =", special.erf(x))
print("erfc (x) =", special.erfc(x))
print("erfinv (x) =", special.erfcinv(x))
# Out:
# erf (x) = [0.32862676 0.67780119 0.74210096 0.84270079]
# erfc (x) = [0.67137324 0.32219881 0.25789904 0.15729921]
# erfinv (x) = [ 0.73286908  0.27246271  0.17914345 -0.        ]
