# %%
import numpy as np

# %%
x = np.array([
    [1,2,3],
    [3,4,6],
    [3,6,4],
    [9,7,4]
])

print('Numpy: \n', x)
# Out:
# Numpy:
#  [[1 2 3]
#  [3 4 6]
#  [3 6 4]
#  [9 7 4]]

# %%
y = x[:,0]
print('x[:,0]: \n', y)
# Out:
# x[:,0]:
#  [1 3 3 9]

# %%
z = x[1,:]
print('x[1,:]: \n', z)
# Out:
# x[1,:]:
#  [3 4 6]

# %%
a = x[1:]
print('x[1:]: \n', a)
# Out:
# x[1:]:
#  [[3 4 6]
#  [3 6 4]
#  [9 7 4]]
