# %% [markdown]
# # Section 71 - Float anomalies in Numpy Arange

# %%
import numpy as np

# %%
for i in np.arange(0.0, 2.1, 0.1):
    print(i)
# Out:
# 0.0
# 0.1
# 0.2
# 0.30000000000000004
# 0.4
# 0.5
# 0.6000000000000001
# 0.7000000000000001
# 0.8
# 0.9
# 1.0
# 1.1
# 1.2000000000000002
# 1.3
# 1.4000000000000001
# 1.5
# 1.6
# 1.7000000000000002
# 1.8
# 1.9000000000000001
# 2.0
