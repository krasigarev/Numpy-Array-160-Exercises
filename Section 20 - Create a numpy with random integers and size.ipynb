# %%
import numpy as np

# %%
a = np.random.randint(1, 20, size=(2,3))
print(a, 'a.shape', a.shape, '\n')
print('a.shape', a.shape)
# Out:
# [[18  9  9]
#  [14  1  3]] a.shape (2, 3)
#
# a.shape (2, 3)
