# %%
import numpy as np

# %%
a = np.random.randint(0, 10, 20).reshape(4,5)

print(a)
# Out:
# [[4 1 4 0 9]
#  [2 2 1 2 4]
#  [9 5 3 3 0]
#  [0 6 9 2 0]]

# %%
b = a[:,4] > 2

print(b)
# Out:
# [ True  True False False]

# %%
c = a[2,:] > 2
print(c)
# Out:
# [ True  True  True  True False]
