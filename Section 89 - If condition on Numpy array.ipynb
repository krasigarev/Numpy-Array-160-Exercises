# %%
import numpy as np

# %%
a = np.arange(3).view([('b', np.int32), ('c', np.int32)])
print(a)
# Out:
# [(0, 0) (1, 0) (2, 0)]

# %%
print(a['b'] < 4)
# Out:
# [ True  True  True]

# %%
print((a['b'] < 4).sum())
# Out:
# 3
