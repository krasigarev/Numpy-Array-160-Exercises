# %%
import numpy as np

# %%
a = np.array([[1,2], [3,4]])

# %%
a
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
a.T
# Out:
# array([[1, 3],
#        [2, 4]])

# %%
a.transpose()
# Out:
# array([[1, 3],
#        [2, 4]])
