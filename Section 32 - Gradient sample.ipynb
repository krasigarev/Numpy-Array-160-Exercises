# %%
import numpy as np

# %%
a = np.array([1,3, 4], dtype=float)
print('Original: \n',a)
# Out:
# Original:
#  [1. 3. 4.]

# %%
b = np.gradient(a)
print("After Gradient : \n",b)
# Out:
# After Gradient :
#  [2.  1.5 1. ]

# %%
c = np.gradient(a, 2)
print('After gradient: \n', c)
# Out:
# After gradient:
#  [1.   0.75 0.5 ]
