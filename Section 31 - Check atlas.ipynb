# %%
import numpy as np

# %%
import numpy.distutils.system_info as sysinfo
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import numpy.distutils.system_info as sysinfo
#
# ModuleNotFoundError: No module named 'numpy.distutils'
