# %%
import numpy as np
import itertools

# %%
a_List = ['CA', 'BA', 'BJ']
print('Original: \n', a_List)
# Out:
# Original:
#  ['CA', 'BA', 'BJ']

# %%
rotation = 50
icc = itertools.cycle(a_List)
a = [next(icc) for _ in range(rotation)]
print(a)
# Out:
# ['CA', 'BA', 'BJ', 'CA', 'BA', 'BJ', 'CA', 'BA', 'BJ', 'CA', 'BA', 'BJ', 'CA', 'BA', 'BJ', 'CA', 'BA', 'BJ', 'CA', 'BA', 'BJ', 'CA', 'BA', 'BJ', 'CA', 'BA', 'BJ', 'CA', 'BA', 'BJ', 'CA', 'BA', 'BJ', 'CA', 'BA', 'BJ', 'CA', 'BA', 'BJ', 'CA', 'BA', 'BJ', 'CA', 'BA', 'BJ', 'CA', 'BA', 'BJ', 'CA', 'BA']

# %%
b = np.resize(a_List, rotation)
print(b)
# Out:
# ['CA' 'BA' 'BJ' 'CA' 'BA' 'BJ' 'CA' 'BA' 'BJ' 'CA' 'BA' 'BJ' 'CA' 'BA'
#  'BJ' 'CA' 'BA' 'BJ' 'CA' 'BA' 'BJ' 'CA' 'BA' 'BJ' 'CA' 'BA' 'BJ' 'CA'
#  'BA' 'BJ' 'CA' 'BA' 'BJ' 'CA' 'BA' 'BJ' 'CA' 'BA' 'BJ' 'CA' 'BA' 'BJ'
#  'CA' 'BA' 'BJ' 'CA' 'BA' 'BJ' 'CA' 'BA']
