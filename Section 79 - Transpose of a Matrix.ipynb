# %%
import numpy as np

# %%
a = np.arange(6).reshape(2, -1)
print(a)
# Out:
# [[0 1 2]
#  [3 4 5]]

# %%
b = a.transpose()
print(b)
# Out:
# [[0 3]
#  [1 4]
#  [2 5]]

# %%
c = np.transpose(a)
print(c)
# Out:
# [[0 3]
#  [1 4]
#  [2 5]]
