# %%
import numpy as np

# %%
a = np.searchsorted([1,2,3,4,5], 3)
print(a)
# Out:
# 2

# %%
b = np.searchsorted([1,2,3,4,5], [7,2,3])
print(b)
# Out:
# [5 1 2]

# %%
in_arr = [2,3,4,5,6]

print('Input array: ', in_arr)
# Out:
# Input array:  [2, 3, 4, 5, 6]

# %%
num = 4
print(num)
# Out:
# 4

# %%
out_ind = np.searchsorted(in_arr, num, side='right')
print(out_ind)
# Out:
# 3

# %%
out_ind_1 = np.searchsorted(in_arr, num, side='left')
print(out_ind_1)
# Out:
# 2
