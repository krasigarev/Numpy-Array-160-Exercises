# %%
import numpy as np

# %%
x = np.array(['To'], dtype=str)
y = x.view('S1').reshape(x.size, -1)
print(y)
# Out:
# [[b'T' b'' b'' b'' b'o' b'' b'' b'']]

# %%
x = np.array(['To'], dtype=np.str_)
y = x.view('S1').reshape(x.size, -1)
print(y)
# Out:
# [[b'T' b'' b'' b'' b'o' b'' b'' b'']]
