# %%
import numpy as np

# %%
x = np.array([
    [
        [1],
        [2],
        [3]
    ]
])

print(x)
# Out:
# [[[1]
#   [2]
#   [3]]]

# %%
y = np.squeeze(x)
print(y)
print(y.shape)
# Out:
# [1 2 3]
# (3,)
